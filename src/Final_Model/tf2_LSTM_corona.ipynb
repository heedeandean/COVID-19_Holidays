# %% [markdown]
# # INFOMATION
#
# ## python info
#  - Version : 3.6.10
#  - Anaconda ver 4.8.2
#
# ## package info
#  - tensorflow ver 2.1.0
#  - numpy ver 1.19.1
#  - pandas ver 1.1.1

# %%
# ##########################################
# # 환경 변경 또는 다운로드를 원할때 사용하세요
# # 전체를 드래그 후 ctrl+/ 누르면 활성화 됩니다.
# !pip install tensorflow==2.1
# !pip install numpy==1.19.1
# !pip install pandas==1.1.1
# !pip install varname
# !pip install qgrid
# !pip install pymysql
# ##########################################

# tensorflow
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping

import os

# data array
import pandas as pd
from datetime import datetime, date
import numpy as np

# print 내 지수표현식 방지
np.set_printoptions(formatter={'float_kind': lambda x: "{0:0.2f}".format(x)})

# nomalization
from sklearn.preprocessing import MinMaxScaler as scaler
from sklearn.metrics import mean_squared_error

# return variable name
from varname import nameof

# dataframe visualization
import qgrid

# %% [markdown]
# - matplotlib 오류 방지

# %%
import matplotlib
if "DISPLAY" not in os.environ:
    # remove Travis CI Error
    matplotlib.use('TkAgg')

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # SETTING
#  ### function

# %%
def build_dataset(time_series, seq_length):
    dataX = []
    dataY = []
    for i in range(0, len(time_series) - seq_length):
        x = time_series[i : i + seq_length,:-1]
        y = time_series[i + seq_length, [-1]]

        dataX.append(x)
        dataY.append(y)
        if i <=10:
            print('{}번째'.format(i))
            print(x, "->", y)
            print('='*10)
            
    return np.array(dataX), np.array(dataY)

def build_dataset_x(time_series, seq_length):
    dataX = []
    for i in range(0, len(time_series) - seq_length):
        x = time_series[i : i + seq_length,:]
        dataX.append(x)
        if i <=10:
            print('{}번째'.format(i))
            print(x)
            print('='*10)
    return np.array(dataX)

def series_diff(data, data_col, start_date, mid_date, end_date, col):
    cfm_date = list(data['cfm_date'])
    date_idx = pd.to_datetime(cfm_date)
    
    prd_data = data[data_col]
    prd_data = pd.DataFrame(np.array(prd_data), columns=data_col, index=date_idx)
    
    mid_date_ = date.fromisoformat(mid_date)
    next_mid_date = mid_date_.replace(day=mid_date_.day + 1).isoformat()

    diff_polyfit = prd_data.loc[start_date:mid_date,col]
    diff_prd = prd_data.loc[next_mid_date:end_date,col]
    
    return prd_data, diff_polyfit, diff_prd


def polyfit_prd(diff_polyfit, diff_prd, col, periods = 0):
    nd_diff_polyfit = np.array(diff_polyfit)
    nd_diff_prd = np.array(diff_prd)
    
    diff_polyfit = pd.DataFrame(diff_polyfit,columns=[col])
    diff_prd = pd.DataFrame(diff_prd,columns=[col])
    
    polyfit = np.polyfit(np.arange(0,nd_diff_polyfit.shape[0]),nd_diff_polyfit,1)
    
    def f(x):
        dataX=[]
        for i in x:
            if i > 0:
                dataX.append(i)
            else:
                dataX.append(0)
        
        return dataX
    
    poly_inv = polyfit[0]  \
                * np.arange(0,nd_diff_polyfit.shape[0]) \
                + polyfit[1]
    poly_inv = f(poly_inv)
    
    prd_fit = polyfit[0]  \
                * np.arange(nd_diff_polyfit.shape[0],nd_diff_polyfit.shape[0]+nd_diff_prd.shape[0]) \
                + polyfit[1]
    prd_fit = f(prd_fit)
    
    list_prd = polyfit[0]  \
                * np.arange(nd_diff_polyfit.shape[0]+nd_diff_prd.shape[0],
                            nd_diff_polyfit.shape[0]+nd_diff_prd.shape[0]+periods) \
                + polyfit[1]
    list_prd = f(list_prd)
    
    print(prd_fit,'\n',list_prd,'\n',list_prd)
    w, b = polyfit # weight, bias
    print('{} 추세선 값  = w :  {}/ b : {}'.format(col, w, b))
    
    diff_prd['prd_{}'.format(col)] = np.array(prd_fit)
    
    diff_polyfit['prd_{}'.format(col)] = np.array(poly_inv)
    
    return diff_prd, diff_polyfit, list_prd

# %% [markdown]
# ### parameter

# %%
# train Parameters
seq_length = 4
data_dim = 3
output_dim = 1
learning_rate = 0.001
iterations = 1000

# %% [markdown]
# # Preprocess Data
#  ### load data

# %%
try:
    
    import pymysql

    col_name = ['cfm_date','symptom','asymptom','research','cfm_cnt','exam_cnt','policy']
    col_name_str = ','.join(col_name)
    sql_gginfo_select = "select {} from GGInternal".format(col_name_str)

    conn = pymysql.connect(
        user='root', 
        passwd='1234', 
        host='127.0.0.1', 
        db='covid19', 
        charset='utf8'
    )

    with conn.cursor() as cur:
        print('connect complete')
        cur.execute(sql_gginfo_select)
        data = cur.fetchall()


        data = pd.DataFrame(data,columns=col_name)

    spd_symptom = 3.5
    spd_asymptom = 0.8

    data['spread'] = data['symptom'] * (spd_symptom * 0.01) + data['asymptom'] * (spd_asymptom * 0.01)

    xy = data[['cfm_date','exam_cnt','spread','policy','cfm_cnt']]
    
    
    

except:
    print('DB 접속 실패')
    data = pd.read_csv('data.csv')
    
    spd_symptom = 3.5
    spd_asymptom = 0.8
    
    data['spread'] = data['symptom'] * (spd_symptom * 0.01) + data['asymptom'] * (spd_asymptom * 0.01)

    xy = data[['cfm_date','exam_cnt','spread','policy','cfm_cnt']]
# Out:
# DB 접속 실패

# %% [markdown]
# ### 시계열 컬럼 삭제 및 부동소수점으로 변환

# %%
try:
    del xy['cfm_date']
except:
    del xy['date']

xy = xy.values.astype(np.float)
# xy = xy[::-1]  # reverse order (chronically ordered) <- already reverse

# %% [markdown]
# ### 데이터 시각화

# %%
scal = scaler()
scal_tf = scal.fit_transform(xy)
try:
    ts_xy = pd.DataFrame(scal_tf).set_index(data['cfm_date'])
except:
    ts_xy = pd.DataFrame(scal_tf, index = data['date'])
    

plt.figure(figsize=(20,10))
plt.plot(pd.to_datetime(ts_xy.index,format='%Y-%m-%d'),ts_xy[0], linestyle='-', marker=None, label = 'examcnt')
plt.plot(pd.to_datetime(ts_xy.index,format='%Y-%m-%d'),ts_xy[1], linestyle='-', marker=None, label = 'spread')
plt.plot(pd.to_datetime(ts_xy.index,format='%Y-%m-%d'),ts_xy[2], linestyle='-', marker=None, label = 'policy')
plt.plot(pd.to_datetime(ts_xy.index,format='%Y-%m-%d'),ts_xy[3], linestyle='-', marker=None, label = 'infection')
plt.xticks(rotation=90)
plt.xticks(fontsize=20)
plt.grid(b=True, axis='both', linestyle='-')
plt.legend(loc='upper left',fontsize = 20)


plt.gcf().autofmt_xdate()
plt.tight_layout()

plt.show()

# %% [markdown]
# ### 학습용 / 테스트용 분리

# %%
size_rate = 0.95
train_size = int(len(xy) * size_rate)
train_set = xy[0:train_size]
test_set = xy[train_size - seq_length:]
train_set
# Out:
# array([[119.00, 0.04, 0.00, 1.00],
#        [55.00, 0.04, 0.00, 1.00],
#        [105.00, 0.04, 0.00, 1.00],
#        [498.00, 0.04, 0.00, 1.00],
#        [512.00, 0.04, 0.00, 1.00],
#        [1053.00, 0.01, 0.00, 1.00],
#        [1976.00, 0.04, 0.00, 1.00],
#        [3098.00, 0.07, 0.00, 2.00],
#        [4957.00, 0.12, 0.00, 7.00],
#        [4424.00, 0.35, 0.00, 10.00],
#        [6346.00, 0.29, 0.00, 9.00],
#        [7404.00, 0.21, 0.00, 6.00],
#        [12965.00, 0.29, 0.00, 9.00],
#        [12594.00, 0.37, 0.00, 13.00],
#        [13944.00, 0.23, 0.00, 8.00],
#        [12075.00, 0.33, 0.00, 11.00],
#        [4280.00, 0.07, 0.00, 2.00],
#        [10194.00, 0.07, 0.00, 2.00],
#        [15660.00, 0.28, 0.00, 8.00],
#        [10340.00, 0.35, 0.00, 10.00],
#        [9396.00, 0.36, 0.00, 11.00],
#        [17681.00, 0.39, 0.00, 13.00],
#        [12966.00, 0.18, 0.00, 6.00],
#        [9962.00, 0.24, 0.00, 11.00],
#        [7852.00, 0.34, 0.00, 12.00],
#        [13395.00, 0.35, 0.00, 10.00],
#        [12009.00, 0.14, 0.00, 4.00],
#        [12489.00, 0.09, 0.00, 5.00],
#        [13539.00, 0.37, 0.00, 13.00],
#        [12581.00, 0.27, 0.00, 10.00],
#        [6801.00, 0.45, 0.00, 19.00],
#        [6218.00, 0.80, 0.00, 32.00],
#        [12128.00, 0.34, 0.00, 12.00],
#        [8838.00, 0.51, 0.00, 16.00],
#        [11225.00, 0.29, 0.00, 9.00],
#        [9553.00, 0.19, 0.00, 7.00],
#        [10698.00, 0.36, 0.00, 15.00],
#        [4173.00, 0.22, 1.50, 11.00],
#        [6192.00, 0.15, 1.50, 8.00],
#        [10470.00, 0.37, 1.50, 13.00],
#        [9214.00, 0.29, 1.50, 9.00],
#        [6942.00, 0.34, 1.50, 12.00],
#        [11928.00, 0.23, 1.50, 9.00],
#        [10818.00, 0.18, 1.50, 6.00],
#        [6111.00, 0.14, 1.50, 4.00],
#        [975.00, 0.16, 1.50, 6.00],
#        [15245.00, 0.33, 1.50, 14.00],
#        [10882.00, 0.27, 1.50, 10.00],
#        [10107.00, 0.36, 1.50, 18.00],
#        [11444.00, 0.41, 1.50, 14.00],
#        [11665.00, 0.19, 1.50, 7.00],
#        [6120.00, 0.09, 1.50, 4.00],
#        [5524.00, 0.16, 1.50, 6.00],
#        [10453.00, 0.15, 1.50, 5.00],
#        [8646.00, 0.09, 1.50, 4.00],
#        [8669.00, 0.18, 1.50, 5.00],
#        [8313.00, 0.16, 1.50, 6.00],
#        [7398.00, 0.12, 1.50, 5.00],
#        [4097.00, 0.21, 1.50, 6.00],
#        [8668.00, 0.08, 1.50, 3.00],
#        [7087.00, 0.04, 1.50, 1.00],
#        [4201.00, 0.04, 1.50, 1.00],
#        [7666.00, 0.09, 1.50, 4.00],
#        [4267.00, 0.01, 1.50, 1.00],
#        [3913.00, 0.04, 1.00, 1.00],
#        [6934.00, 0.01, 1.00, 1.00],
#        [6004.00, 0.04, 1.00, 1.00],
#        [5543.00, 0.07, 1.00, 2.00],
#        [5631.00, 0.01, 1.00, 1.00],
#        [3114.00, 0.04, 1.00, 1.00],
#        [6840.00, 0.04, 1.00, 1.00],
#        [2856.00, 0.04, 1.00, 1.00],
#        [6289.00, 0.04, 1.00, 1.00],
#        [5463.00, 0.08, 1.00, 3.00],
#        [5149.00, 0.18, 1.00, 6.00],
#        [3822.00, 0.09, 1.00, 4.00],
#        [4571.00, 0.17, 1.00, 8.00],
#        [12371.00, 0.04, 1.00, 1.00],
#        [15004.00, 0.16, 1.00, 6.00],
#        [15535.00, 0.07, 1.00, 2.00],
#        [15236.00, 0.04, 1.00, 1.00],
#        [13879.00, 0.04, 1.00, 1.00],
#        [6995.00, 0.04, 1.00, 1.00],
#        [5543.00, 0.07, 1.00, 2.00],
#        [12350.00, 0.16, 1.00, 6.00],
#        [10827.00, 0.14, 1.00, 4.00],
#        [12239.00, 0.08, 1.00, 3.00],
#        [13714.00, 0.37, 1.00, 13.00],
#        [11979.00, 0.18, 1.00, 5.00],
#        [5844.00, 0.18, 1.00, 5.00],
#        [6132.00, 0.07, 1.00, 2.00],
#        [13019.00, 0.15, 1.00, 5.00],
#        [13361.00, 0.68, 1.00, 21.00],
#        [15711.00, 0.43, 1.00, 19.00],
#        [16396.00, 0.22, 1.00, 12.00],
#        [17742.00, 0.19, 1.00, 7.00],
#        [7894.00, 0.33, 1.00, 11.00],
#        [10534.00, 0.38, 1.00, 15.00],
#        [18422.00, 0.29, 1.00, 12.00],
#        [16952.00, 0.34, 1.00, 12.00],
#        [16967.00, 0.23, 1.00, 9.00],
#        [17063.00, 0.16, 1.00, 6.00],
#        [14294.00, 0.61, 1.00, 19.00],
#        [7407.00, 0.22, 1.00, 7.00],
#        [5407.00, 0.35, 1.00, 13.00],
#        [17745.00, 0.73, 1.00, 24.00],
#        [15925.00, 0.28, 1.00, 11.00],
#        [14871.00, 0.50, 1.00, 18.00],
#        [14543.00, 0.43, 1.00, 13.00],
#        [13169.00, 0.27, 1.00, 10.00],
#        [5590.00, 0.14, 1.00, 6.00],
#        [5355.00, 0.11, 1.00, 4.00],
#        [14014.00, 0.43, 1.00, 13.00],
#        [13013.00, 0.32, 1.00, 13.00],
#        [12830.00, 0.26, 1.00, 9.00],
#        [12302.00, 0.27, 1.00, 10.00],
#        [12771.00, 0.28, 1.00, 11.00],
#        [5514.00, 0.04, 1.00, 2.00],
#        [5586.00, 0.07, 1.00, 2.00],
#        [13900.00, 0.19, 1.00, 7.00],
#        [12534.00, 0.18, 1.00, 6.00],
#        [11853.00, 0.11, 1.00, 3.00],
#        [11798.00, 0.20, 1.00, 13.00],
#        [11414.00, 0.41, 1.00, 14.00],
#        [7853.00, 0.40, 1.00, 13.00],
#        [8217.00, 0.21, 1.00, 6.00],
#        [13769.00, 0.33, 1.00, 11.00],
#        [11415.00, 0.14, 1.00, 4.00],
#        [10677.00, 0.49, 1.00, 17.00],
#        [11736.00, 0.31, 1.00, 13.00],
#        [11699.00, 0.09, 1.00, 4.00],
#        [6473.00, 0.16, 1.00, 6.00],
#        [5693.00, 0.21, 1.00, 6.00],
#        [14354.00, 0.25, 1.00, 11.00],
#        [13478.00, 0.04, 1.00, 1.00],
#        [11987.00, 0.08, 1.00, 3.00],
#        [13074.00, 0.11, 1.00, 3.00],
#        [12016.00, 0.23, 1.00, 9.00],
#        [5159.00, 0.04, 1.00, 1.00],
#        [6106.00, 0.14, 1.00, 4.00],
#        [12271.00, 0.08, 1.00, 3.00],
#        [10661.00, 0.08, 1.00, 3.00],
#        [9971.00, 0.15, 1.00, 5.00],
#        [9609.00, 0.07, 1.00, 2.00],
#        [4868.00, 0.04, 1.00, 1.00],
#        [12152.00, 0.25, 1.00, 8.00],
#        [9618.00, 0.38, 1.00, 17.00],
#        [8724.00, 0.12, 1.00, 5.00],
#        [9432.00, 0.22, 1.00, 11.00],
#        [8194.00, 0.12, 1.00, 5.00],
#        [4234.00, 0.04, 1.00, 2.00],
#        [4023.00, 0.04, 1.00, 1.00],
#        [10702.00, 0.09, 1.00, 5.00],
#        [9555.00, 0.14, 1.00, 4.00],
#        [8890.00, 0.09, 1.00, 4.00],
#        [7545.00, 0.18, 1.00, 5.00],
#        [8003.00, 0.04, 1.00, 1.00],
#        [4386.00, 0.04, 1.00, 1.00],
#        [3488.00, 0.08, 1.00, 3.00],
#        [9989.00, 0.02, 1.00, 2.00],
#        [8374.00, 0.30, 1.00, 11.00],
#        [8257.00, 0.12, 1.00, 5.00],
#        [7145.00, 0.30, 1.00, 11.00],
#        [6819.00, 0.33, 1.00, 14.00],
#        [4100.00, 0.09, 1.00, 4.00],
#        [3625.00, 0.19, 1.00, 7.00],
#        [9507.00, 0.64, 1.00, 19.00],
#        [8754.00, 0.43, 1.00, 17.00],
#        [8190.00, 1.08, 1.00, 37.00],
#        [10083.00, 2.79, 1.00, 106.00],
#        [10046.00, 1.92, 1.00, 74.00],
#        [6212.00, 1.62, 1.00, 71.00],
#        [6486.00, 1.36, 1.00, 55.00],
#        [8326.00, 2.08, 2.00, 89.00],
#        [17725.00, 2.55, 2.00, 97.00],
#        [18731.00, 2.59, 2.00, 104.00],
#        [19716.00, 2.49, 2.00, 97.00],
#        [21345.00, 3.24, 2.00, 119.00],
#        [14989.00, 1.96, 2.00, 73.00],
#        [12970.00, 1.68, 2.00, 62.00],
#        [21135.00, 2.36, 2.00, 82.00],
#        [23349.00, 2.86, 2.00, 94.00],
#        [19632.00, 2.98, 2.00, 121.00],
#        [17767.00, 1.98, 2.00, 96.00],
#        [21289.00, 2.37, 2.00, 83.00],
#        [14542.00, 1.54, 2.50, 64.00],
#        [13271.00, 1.41, 2.50, 58.00],
#        [21156.00, 2.35, 2.50, 84.00],
#        [20948.00, 1.85, 2.50, 63.00],
#        [20062.00, 1.43, 2.50, 51.00],
#        [18156.00, 0.98, 2.50, 43.00],
#        [17971.00, 1.29, 2.50, 46.00],
#        [8723.00, 0.77, 2.50, 29.00],
#        [5243.00, 0.94, 2.50, 36.00],
#        [14645.00, 1.22, 2.50, 44.00],
#        [16000.00, 1.20, 2.50, 49.00],
#        [17202.00, 1.15, 2.50, 46.00],
#        [19444.00, 0.77, 2.50, 26.00]])

# %% [markdown]
#  ### 스케일링 (Min-Max Scaling)
#      > 1. x, y 스케일러 인스턴스 생성
#      > 2. x, y 전체 피팅 생성
#      > 3. 학습용 / 테스트용 스케일링 변환
#      >> * 나누는 목적
#      >>> 나중에 inverse 할때 예상값과 같은 배열 크기여야 가능하다.

# %%
min_max_x = scaler()
min_max_y = scaler()

min_max_x_fit = min_max_x.fit(xy[:,:-1])
min_max_y_fit = min_max_y.fit(xy[:,[-1]])

train_set_sc_x = min_max_x.transform(train_set[:, :-1])
train_set_sc_y = min_max_y.transform(train_set[:, [-1]])
test_set_sc_x = min_max_x.transform(test_set[:, :-1])
test_set_sc_y = min_max_y.transform(test_set[:, [-1]])

print(train_set_sc_x[:10])
print('-'*10)
print(train_set[:10])
print('-'*10)
print(min_max_x.inverse_transform(train_set_sc_x)[:10])
# Out:
# [[0.00 0.01 0.00]
#  [0.00 0.01 0.00]
#  [0.00 0.01 0.00]
#  [0.02 0.01 0.00]
#  [0.02 0.01 0.00]
#  [0.04 0.00 0.00]
#  [0.08 0.01 0.00]
#  [0.13 0.02 0.00]
#  [0.21 0.03 0.00]
#  [0.19 0.11 0.00]]
# ----------
# [[119.00 0.04 0.00 1.00]
#  [55.00 0.04 0.00 1.00]
#  [105.00 0.04 0.00 1.00]
#  [498.00 0.04 0.00 1.00]
#  [512.00 0.04 0.00 1.00]
#  [1053.00 0.01 0.00 1.00]
#  [1976.00 0.04 0.00 1.00]
#  [3098.00 0.07 0.00 2.00]
#  [4957.00 0.12 0.00 7.00]
#  [4424.00 0.35 0.00 10.00]]
# ----------
# [[119.00 0.04 0.00]
#  [55.00 0.04 0.00]
#  [105.00 0.04 0.00]
#  [498.00 0.04 0.00]
#  [512.00 0.04 0.00]
#  [1053.00 0.01 0.00]
#  [1976.00 0.04 0.00]
#  [3098.00 0.07 0.00]
#  [4957.00 0.12 0.00]
#  [4424.00 0.35 0.00]]

# %% [markdown]
#  ### 스케일링 데이터 합치기

# %%
train_set = np.concatenate((train_set_sc_x,train_set_sc_y), axis=1)
test_set = np.concatenate((test_set_sc_x,test_set_sc_y), axis=1)
print(train_set[:3])
print('-'*10)
print(test_set[:3])
# Out:
# [[0.00 0.01 0.00 0.00]
#  [0.00 0.01 0.00 0.00]
#  [0.00 0.01 0.00 0.00]]
# ----------
# [[0.63 0.37 1.00 0.36]
#  [0.68 0.37 1.00 0.40]
#  [0.74 0.35 1.00 0.37]]

# %% [markdown]
#  ### 학습 / 테스트 데이터 구분

# %%
print('Data Name is {}'.format(nameof(train_set)))
trainX, trainY = build_dataset(train_set, seq_length)

print('\n\n')

print('Data Name is {}'.format(nameof(test_set)))
testX, testY = build_dataset(test_set, seq_length)

print(trainX.shape,testX.shape)
# Out:
# Data Name is train_set
# 0번째
# [[0.00 0.01 0.00]
#  [0.00 0.01 0.00]
#  [0.00 0.01 0.00]
#  [0.02 0.01 0.00]] -> [0.00]
# ==========
# 1번째
# [[0.00 0.01 0.00]
#  [0.00 0.01 0.00]
#  [0.02 0.01 0.00]
#  [0.02 0.01 0.00]] -> [0.00]
# ==========
# 2번째
# [[0.00 0.01 0.00]
#  [0.02 0.01 0.00]
#  [0.02 0.01 0.00]
#  [0.04 0.00 0.00]] -> [0.00]
# ==========
# 3번째
# [[0.02 0.01 0.00]
#  [0.02 0.01 0.00]
#  [0.04 0.00 0.00]
#  [0.08 0.01 0.00]] -> [0.01]
# ==========
# 4번째
# [[0.02 0.01 0.00]
#  [0.04 0.00 0.00]
#  [0.08 0.01 0.00]
#  [0.13 0.02 0.00]] -> [0.05]
# ==========
# 5번째
# [[0.04 0.00 0.00]
#  [0.08 0.01 0.00]
#  [0.13 0.02 0.00]
#  [0.21 0.03 0.00]] -> [0.07]
# ==========
# 6번째
# [[0.08 0.01 0.00]
#  [0.13 0.02 0.00]
#  [0.21 0.03 0.00]
#  [0.19 0.11 0.00]] -> [0.07]
# ==========
# 7번째
# [[0.13 0.02 0.00]
#  [0.21 0.03 0.00]
#  [0.19 0.11 0.00]
#  [0.27 0.09 0.00]] -> [0.04]
# ==========
# 8번째
# [[0.21 0.03 0.00]
#  [0.19 0.11 0.00]
#  [0.27 0.09 0.00]
#  [0.32 0.06 0.00]] -> [0.07]
# ==========
# 9번째
# [[0.19 0.11 0.00]
#  [0.27 0.09 0.00]
#  [0.32 0.06 0.00]
#  [0.55 0.09 0.00]] -> [0.10]
# ==========
# 10번째
# [[0.27 0.09 0.00]
#  [0.32 0.06 0.00]
#  [0.55 0.09 0.00]
#  [0.54 0.11 0.00]] -> [0.06]
# ==========
#
#
#
# Data Name is test_set
# 0번째
# [[0.63 0.37 1.00]
#  [0.68 0.37 1.00]
#  [0.74 0.35 1.00]
#  [0.83 0.23 1.00]] -> [0.23]
# ==========
# 1번째
# [[0.68 0.37 1.00]
#  [0.74 0.35 1.00]
#  [0.83 0.23 1.00]
#  [0.69 0.23 1.00]] -> [0.23]
# ==========
# 2번째
# [[0.74 0.35 1.00]
#  [0.83 0.23 1.00]
#  [0.69 0.23 1.00]
#  [0.33 0.28 1.00]] -> [0.25]
# ==========
# 3번째
# [[0.83 0.23 1.00]
#  [0.69 0.23 1.00]
#  [0.33 0.28 1.00]
#  [0.32 0.24 0.80]] -> [0.21]
# ==========
# 4번째
# [[0.69 0.23 1.00]
#  [0.33 0.28 1.00]
#  [0.32 0.24 0.80]
#  [0.58 0.23 0.80]] -> [0.42]
# ==========
# 5번째
# [[0.33 0.28 1.00]
#  [0.32 0.24 0.80]
#  [0.58 0.23 0.80]
#  [0.60 0.44 0.80]] -> [0.27]
# ==========
# 6번째
# [[0.32 0.24 0.80]
#  [0.58 0.23 0.80]
#  [0.60 0.44 0.80]
#  [0.55 0.21 0.80]] -> [0.32]
# ==========
# 7번째
# [[0.58 0.23 0.80]
#  [0.60 0.44 0.80]
#  [0.55 0.21 0.80]
#  [0.61 0.29 0.80]] -> [0.18]
# ==========
# 8번째
# [[0.60 0.44 0.80]
#  [0.55 0.21 0.80]
#  [0.61 0.29 0.80]
#  [0.54 0.19 0.80]] -> [0.14]
# ==========
# 9번째
# [[0.55 0.21 0.80]
#  [0.61 0.29 0.80]
#  [0.54 0.19 0.80]
#  [0.32 0.14 0.80]] -> [0.12]
# ==========
# 10번째
# [[0.61 0.29 0.80]
#  [0.54 0.19 0.80]
#  [0.32 0.14 0.80]
#  [0.20 0.12 0.80]] -> [0.22]
# ==========
# (194, 4, 3) (11, 4, 3)

# %% [markdown]
#  # LSTM Modeling
#   ### 셀 지정

# %%
# tf.random.set_seed(777)
tf.model = tf.keras.Sequential()
tf.model.add(tf.keras.layers.LSTM(units=5,input_shape=(seq_length, data_dim), return_sequences=True))
tf.model.add(tf.keras.layers.LSTM(units=5, return_sequences=False))
tf.model.add(tf.keras.layers.Dense(units=output_dim, activation='linear'))
tf.model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 4, 5)              180
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 5)                 220
# _________________________________________________________________
# dense (Dense)                (None, 1)                 6
# =================================================================
# Total params: 406
# Trainable params: 406
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
#  ### Compile 지정

# %%
tf.model.compile(loss='mse',
                 # optimizer=tf.keras.optimizers.Adam(lr=learning_rate),
                 optimizer='adam',
                 metrics=['accuracy'])

es = EarlyStopping(monitor='val_loss', mode='min',patience = 40)

h = tf.model.fit(trainX, trainY,
                 epochs=iterations,
                 batch_size=7,
                 validation_data=[testX,testY],
                 verbose=1,
                 callbacks = [es]
                )
# Out:
# Train on 194 samples, validate on 11 samples
# Epoch 1/1000
# 194/194 [==============================] - 2s 12ms/sample - loss: 0.0537 - accuracy: 0.1237 - val_loss: 0.0292 - val_accuracy: 0.0000e+00
# Epoch 2/1000
# 194/194 [==============================] - 0s 632us/sample - loss: 0.0419 - accuracy: 0.1237 - val_loss: 0.0147 - val_accuracy: 0.0000e+00
# Epoch 3/1000
# 194/194 [==============================] - 0s 614us/sample - loss: 0.0395 - accuracy: 0.1237 - val_loss: 0.0109 - val_accuracy: 0.0000e+00
# Epoch 4/1000
# 194/194 [==============================] - 0s 612us/sample - loss: 0.0375 - accuracy: 0.1237 - val_loss: 0.0104 - val_accuracy: 0.0000e+00
# Epoch 5/1000
# 194/194 [==============================] - 0s 606us/sample - loss: 0.0342 - accuracy: 0.1237 - val_loss: 0.0086 - val_accuracy: 0.0000e+00
# Epoch 6/1000
# 194/194 [==============================] - 0s 621us/sample - loss: 0.0300 - accuracy: 0.1237 - val_loss: 0.0068 - val_accuracy: 0.0000e+00
# Epoch 7/1000
# 194/194 [==============================] - 0s 628us/sample - loss: 0.0252 - accuracy: 0.1237 - val_loss: 0.0078 - val_accuracy: 0.0000e+00
# Epoch 8/1000
# 194/194 [==============================] - 0s 605us/sample - loss: 0.0206 - accuracy: 0.1237 - val_loss: 0.0124 - val_accuracy: 0.0000e+00
# Epoch 9/1000
# 194/194 [==============================] - 0s 611us/sample - loss: 0.0170 - accuracy: 0.1237 - val_loss: 0.0209 - val_accuracy: 0.0000e+00
# Epoch 10/1000
# 194/194 [==============================] - 0s 613us/sample - loss: 0.0150 - accuracy: 0.1289 - val_loss: 0.0206 - val_accuracy: 0.0000e+00
# Epoch 11/1000
# 194/194 [==============================] - 0s 612us/sample - loss: 0.0136 - accuracy: 0.1289 - val_loss: 0.0143 - val_accuracy: 0.0000e+00
# Epoch 12/1000
# 194/194 [==============================] - 0s 617us/sample - loss: 0.0127 - accuracy: 0.1289 - val_loss: 0.0126 - val_accuracy: 0.0000e+00
# Epoch 13/1000
# 194/194 [==============================] - 0s 604us/sample - loss: 0.0121 - accuracy: 0.1289 - val_loss: 0.0106 - val_accuracy: 0.0000e+00
# Epoch 14/1000
# 194/194 [==============================] - 0s 579us/sample - loss: 0.0114 - accuracy: 0.1289 - val_loss: 0.0111 - val_accuracy: 0.0000e+00
# Epoch 15/1000
# 194/194 [==============================] - 0s 617us/sample - loss: 0.0113 - accuracy: 0.1289 - val_loss: 0.0096 - val_accuracy: 0.0000e+00
# Epoch 16/1000
# 194/194 [==============================] - 0s 587us/sample - loss: 0.0106 - accuracy: 0.1289 - val_loss: 0.0093 - val_accuracy: 0.0000e+00
# Epoch 17/1000
# 194/194 [==============================] - 0s 586us/sample - loss: 0.0102 - accuracy: 0.1289 - val_loss: 0.0078 - val_accuracy: 0.0000e+00
# Epoch 18/1000
# 194/194 [==============================] - 0s 601us/sample - loss: 0.0104 - accuracy: 0.1289 - val_loss: 0.0127 - val_accuracy: 0.0000e+00
# Epoch 19/1000
# 194/194 [==============================] - 0s 619us/sample - loss: 0.0097 - accuracy: 0.1289 - val_loss: 0.0073 - val_accuracy: 0.0000e+00
# Epoch 20/1000
# 194/194 [==============================] - 0s 602us/sample - loss: 0.0100 - accuracy: 0.1289 - val_loss: 0.0073 - val_accuracy: 0.0000e+00
# Epoch 21/1000
# 194/194 [==============================] - 0s 585us/sample - loss: 0.0099 - accuracy: 0.1289 - val_loss: 0.0083 - val_accuracy: 0.0000e+00
# Epoch 22/1000
# 194/194 [==============================] - 0s 613us/sample - loss: 0.0095 - accuracy: 0.1289 - val_loss: 0.0070 - val_accuracy: 0.0000e+00
# Epoch 23/1000
# 194/194 [==============================] - 0s 601us/sample - loss: 0.0094 - accuracy: 0.1289 - val_loss: 0.0071 - val_accuracy: 0.0000e+00
# Epoch 24/1000
# 194/194 [==============================] - 0s 616us/sample - loss: 0.0090 - accuracy: 0.1289 - val_loss: 0.0073 - val_accuracy: 0.0000e+00
# Epoch 25/1000
# 194/194 [==============================] - 0s 601us/sample - loss: 0.0090 - accuracy: 0.1289 - val_loss: 0.0078 - val_accuracy: 0.0000e+00
# Epoch 26/1000
# 194/194 [==============================] - 0s 604us/sample - loss: 0.0094 - accuracy: 0.1289 - val_loss: 0.0104 - val_accuracy: 0.0000e+00
# Epoch 27/1000
# 194/194 [==============================] - 0s 615us/sample - loss: 0.0091 - accuracy: 0.1289 - val_loss: 0.0069 - val_accuracy: 0.0000e+00
# Epoch 28/1000
# 194/194 [==============================] - 0s 590us/sample - loss: 0.0090 - accuracy: 0.1289 - val_loss: 0.0071 - val_accuracy: 0.0000e+00
# Epoch 29/1000
# 194/194 [==============================] - 0s 597us/sample - loss: 0.0089 - accuracy: 0.1289 - val_loss: 0.0066 - val_accuracy: 0.0000e+00
# Epoch 30/1000
# 194/194 [==============================] - 0s 601us/sample - loss: 0.0093 - accuracy: 0.1289 - val_loss: 0.0066 - val_accuracy: 0.0000e+00
# Epoch 31/1000
# 194/194 [==============================] - 0s 582us/sample - loss: 0.0088 - accuracy: 0.1289 - val_loss: 0.0072 - val_accuracy: 0.0000e+00
# Epoch 32/1000
# 194/194 [==============================] - 0s 578us/sample - loss: 0.0087 - accuracy: 0.1289 - val_loss: 0.0068 - val_accuracy: 0.0000e+00
# Epoch 33/1000
# 194/194 [==============================] - 0s 600us/sample - loss: 0.0088 - accuracy: 0.1289 - val_loss: 0.0066 - val_accuracy: 0.0000e+00
# Epoch 34/1000
# 194/194 [==============================] - 0s 607us/sample - loss: 0.0094 - accuracy: 0.1289 - val_loss: 0.0065 - val_accuracy: 0.0000e+00
# Epoch 35/1000
# 194/194 [==============================] - 0s 634us/sample - loss: 0.0090 - accuracy: 0.1289 - val_loss: 0.0064 - val_accuracy: 0.0000e+00
# Epoch 36/1000
# 194/194 [==============================] - 0s 638us/sample - loss: 0.0081 - accuracy: 0.1289 - val_loss: 0.0089 - val_accuracy: 0.0000e+00
# Epoch 37/1000
# 194/194 [==============================] - 0s 600us/sample - loss: 0.0084 - accuracy: 0.1289 - val_loss: 0.0066 - val_accuracy: 0.0000e+00
# Epoch 38/1000
# 194/194 [==============================] - 0s 615us/sample - loss: 0.0085 - accuracy: 0.1289 - val_loss: 0.0064 - val_accuracy: 0.0000e+00
# Epoch 39/1000
# 194/194 [==============================] - 0s 623us/sample - loss: 0.0086 - accuracy: 0.1289 - val_loss: 0.0070 - val_accuracy: 0.0000e+00
# Epoch 40/1000
# 194/194 [==============================] - 0s 639us/sample - loss: 0.0083 - accuracy: 0.1289 - val_loss: 0.0064 - val_accuracy: 0.0000e+00
# Epoch 41/1000
# 194/194 [==============================] - 0s 608us/sample - loss: 0.0081 - accuracy: 0.1289 - val_loss: 0.0066 - val_accuracy: 0.0000e+00
# Epoch 42/1000
# 194/194 [==============================] - 0s 621us/sample - loss: 0.0084 - accuracy: 0.1289 - val_loss: 0.0063 - val_accuracy: 0.0000e+00
# Epoch 43/1000
# 194/194 [==============================] - 0s 615us/sample - loss: 0.0080 - accuracy: 0.1289 - val_loss: 0.0075 - val_accuracy: 0.0000e+00
# Epoch 44/1000
# 194/194 [==============================] - 0s 602us/sample - loss: 0.0079 - accuracy: 0.1289 - val_loss: 0.0064 - val_accuracy: 0.0000e+00
# Epoch 45/1000
# 194/194 [==============================] - 0s 615us/sample - loss: 0.0077 - accuracy: 0.1289 - val_loss: 0.0064 - val_accuracy: 0.0000e+00
# Epoch 46/1000
# 194/194 [==============================] - 0s 597us/sample - loss: 0.0077 - accuracy: 0.1289 - val_loss: 0.0063 - val_accuracy: 0.0000e+00
# Epoch 47/1000
# 194/194 [==============================] - 0s 623us/sample - loss: 0.0080 - accuracy: 0.1289 - val_loss: 0.0065 - val_accuracy: 0.0000e+00
# Epoch 48/1000
# 194/194 [==============================] - 0s 582us/sample - loss: 0.0080 - accuracy: 0.1289 - val_loss: 0.0069 - val_accuracy: 0.0000e+00
# Epoch 49/1000
# 194/194 [==============================] - 0s 577us/sample - loss: 0.0076 - accuracy: 0.1289 - val_loss: 0.0064 - val_accuracy: 0.0000e+00
# Epoch 50/1000
# 194/194 [==============================] - 0s 568us/sample - loss: 0.0077 - accuracy: 0.1289 - val_loss: 0.0063 - val_accuracy: 0.0000e+00
# Epoch 51/1000
# 194/194 [==============================] - 0s 595us/sample - loss: 0.0075 - accuracy: 0.1289 - val_loss: 0.0065 - val_accuracy: 0.0000e+00
# Epoch 52/1000
# 194/194 [==============================] - 0s 604us/sample - loss: 0.0075 - accuracy: 0.1289 - val_loss: 0.0062 - val_accuracy: 0.0000e+00
# Epoch 53/1000
# 194/194 [==============================] - 0s 586us/sample - loss: 0.0073 - accuracy: 0.1289 - val_loss: 0.0063 - val_accuracy: 0.0000e+00
# Epoch 54/1000
# 194/194 [==============================] - 0s 572us/sample - loss: 0.0073 - accuracy: 0.1289 - val_loss: 0.0064 - val_accuracy: 0.0000e+00
# Epoch 55/1000
# 194/194 [==============================] - 0s 574us/sample - loss: 0.0075 - accuracy: 0.1289 - val_loss: 0.0080 - val_accuracy: 0.0000e+00
# Epoch 56/1000
# 194/194 [==============================] - 0s 569us/sample - loss: 0.0076 - accuracy: 0.1289 - val_loss: 0.0071 - val_accuracy: 0.0000e+00
# Epoch 57/1000
# 194/194 [==============================] - 0s 568us/sample - loss: 0.0072 - accuracy: 0.1289 - val_loss: 0.0065 - val_accuracy: 0.0000e+00
# Epoch 58/1000
# 194/194 [==============================] - 0s 573us/sample - loss: 0.0073 - accuracy: 0.1289 - val_loss: 0.0064 - val_accuracy: 0.0000e+00
# Epoch 59/1000
# 194/194 [==============================] - 0s 565us/sample - loss: 0.0072 - accuracy: 0.1289 - val_loss: 0.0063 - val_accuracy: 0.0000e+00
# Epoch 60/1000
# 194/194 [==============================] - 0s 590us/sample - loss: 0.0071 - accuracy: 0.1289 - val_loss: 0.0063 - val_accuracy: 0.0000e+00
# Epoch 61/1000
# 194/194 [==============================] - 0s 583us/sample - loss: 0.0075 - accuracy: 0.1289 - val_loss: 0.0066 - val_accuracy: 0.0000e+00
# Epoch 62/1000
# 194/194 [==============================] - 0s 569us/sample - loss: 0.0076 - accuracy: 0.1289 - val_loss: 0.0065 - val_accuracy: 0.0000e+00
# Epoch 63/1000
# 194/194 [==============================] - 0s 567us/sample - loss: 0.0081 - accuracy: 0.1289 - val_loss: 0.0068 - val_accuracy: 0.0000e+00
# Epoch 64/1000
# 194/194 [==============================] - 0s 588us/sample - loss: 0.0076 - accuracy: 0.1289 - val_loss: 0.0063 - val_accuracy: 0.0000e+00
# Epoch 65/1000
# 194/194 [==============================] - 0s 613us/sample - loss: 0.0073 - accuracy: 0.1289 - val_loss: 0.0061 - val_accuracy: 0.0000e+00
# Epoch 66/1000
# 194/194 [==============================] - 0s 586us/sample - loss: 0.0073 - accuracy: 0.1289 - val_loss: 0.0074 - val_accuracy: 0.0000e+00
# Epoch 67/1000
# 194/194 [==============================] - 0s 562us/sample - loss: 0.0071 - accuracy: 0.1289 - val_loss: 0.0064 - val_accuracy: 0.0000e+00
# Epoch 68/1000
# 194/194 [==============================] - 0s 574us/sample - loss: 0.0069 - accuracy: 0.1289 - val_loss: 0.0073 - val_accuracy: 0.0000e+00
# Epoch 69/1000
# 194/194 [==============================] - 0s 582us/sample - loss: 0.0071 - accuracy: 0.1289 - val_loss: 0.0063 - val_accuracy: 0.0000e+00
# Epoch 70/1000
# 194/194 [==============================] - 0s 592us/sample - loss: 0.0078 - accuracy: 0.1289 - val_loss: 0.0071 - val_accuracy: 0.0000e+00
# Epoch 71/1000
# 194/194 [==============================] - 0s 601us/sample - loss: 0.0072 - accuracy: 0.1289 - val_loss: 0.0063 - val_accuracy: 0.0000e+00
# Epoch 72/1000
# 194/194 [==============================] - 0s 583us/sample - loss: 0.0068 - accuracy: 0.1289 - val_loss: 0.0067 - val_accuracy: 0.0000e+00
# Epoch 73/1000
# 194/194 [==============================] - 0s 567us/sample - loss: 0.0069 - accuracy: 0.1289 - val_loss: 0.0069 - val_accuracy: 0.0000e+00
# Epoch 74/1000
# 194/194 [==============================] - 0s 580us/sample - loss: 0.0070 - accuracy: 0.1289 - val_loss: 0.0068 - val_accuracy: 0.0000e+00
# Epoch 75/1000
# 194/194 [==============================] - 0s 563us/sample - loss: 0.0072 - accuracy: 0.1289 - val_loss: 0.0070 - val_accuracy: 0.0000e+00
# Epoch 76/1000
# 194/194 [==============================] - 0s 564us/sample - loss: 0.0073 - accuracy: 0.1289 - val_loss: 0.0068 - val_accuracy: 0.0000e+00
# Epoch 77/1000
# 194/194 [==============================] - 0s 563us/sample - loss: 0.0067 - accuracy: 0.1289 - val_loss: 0.0064 - val_accuracy: 0.0000e+00
# Epoch 78/1000
# 194/194 [==============================] - 0s 590us/sample - loss: 0.0067 - accuracy: 0.1289 - val_loss: 0.0064 - val_accuracy: 0.0000e+00
# Epoch 79/1000
# 194/194 [==============================] - 0s 602us/sample - loss: 0.0068 - accuracy: 0.1289 - val_loss: 0.0065 - val_accuracy: 0.0000e+00
# Epoch 80/1000
# 194/194 [==============================] - 0s 585us/sample - loss: 0.0072 - accuracy: 0.1289 - val_loss: 0.0075 - val_accuracy: 0.0000e+00
# Epoch 81/1000
# 194/194 [==============================] - 0s 559us/sample - loss: 0.0072 - accuracy: 0.1289 - val_loss: 0.0064 - val_accuracy: 0.0000e+00
# Epoch 82/1000
# 194/194 [==============================] - 0s 572us/sample - loss: 0.0070 - accuracy: 0.1289 - val_loss: 0.0069 - val_accuracy: 0.0000e+00
# Epoch 83/1000
# 194/194 [==============================] - 0s 585us/sample - loss: 0.0073 - accuracy: 0.1289 - val_loss: 0.0069 - val_accuracy: 0.0000e+00
# Epoch 84/1000
# 194/194 [==============================] - 0s 562us/sample - loss: 0.0070 - accuracy: 0.1289 - val_loss: 0.0063 - val_accuracy: 0.0000e+00
# Epoch 85/1000
# 194/194 [==============================] - 0s 566us/sample - loss: 0.0067 - accuracy: 0.1289 - val_loss: 0.0071 - val_accuracy: 0.0000e+00
# Epoch 86/1000
# 194/194 [==============================] - 0s 581us/sample - loss: 0.0067 - accuracy: 0.1289 - val_loss: 0.0066 - val_accuracy: 0.0000e+00
# Epoch 87/1000
# 194/194 [==============================] - 0s 574us/sample - loss: 0.0067 - accuracy: 0.1289 - val_loss: 0.0065 - val_accuracy: 0.0000e+00
# Epoch 88/1000
# 194/194 [==============================] - 0s 570us/sample - loss: 0.0071 - accuracy: 0.1289 - val_loss: 0.0087 - val_accuracy: 0.0000e+00
# Epoch 89/1000
# 194/194 [==============================] - 0s 565us/sample - loss: 0.0069 - accuracy: 0.1289 - val_loss: 0.0074 - val_accuracy: 0.0000e+00
# Epoch 90/1000
# 194/194 [==============================] - 0s 585us/sample - loss: 0.0070 - accuracy: 0.1289 - val_loss: 0.0070 - val_accuracy: 0.0000e+00
# Epoch 91/1000
# 194/194 [==============================] - 0s 566us/sample - loss: 0.0067 - accuracy: 0.1289 - val_loss: 0.0066 - val_accuracy: 0.0000e+00
# Epoch 92/1000
# 194/194 [==============================] - 0s 558us/sample - loss: 0.0067 - accuracy: 0.1289 - val_loss: 0.0076 - val_accuracy: 0.0000e+00
# Epoch 93/1000
# 194/194 [==============================] - 0s 592us/sample - loss: 0.0069 - accuracy: 0.1289 - val_loss: 0.0074 - val_accuracy: 0.0000e+00
# Epoch 94/1000
# 194/194 [==============================] - 0s 584us/sample - loss: 0.0073 - accuracy: 0.1289 - val_loss: 0.0072 - val_accuracy: 0.0000e+00
# Epoch 95/1000
# 194/194 [==============================] - 0s 566us/sample - loss: 0.0067 - accuracy: 0.1289 - val_loss: 0.0070 - val_accuracy: 0.0000e+00
# Epoch 96/1000
# 194/194 [==============================] - 0s 577us/sample - loss: 0.0065 - accuracy: 0.1289 - val_loss: 0.0065 - val_accuracy: 0.0000e+00
# Epoch 97/1000
# 194/194 [==============================] - 0s 598us/sample - loss: 0.0065 - accuracy: 0.1289 - val_loss: 0.0066 - val_accuracy: 0.0000e+00
# Epoch 98/1000
# 194/194 [==============================] - 0s 581us/sample - loss: 0.0066 - accuracy: 0.1289 - val_loss: 0.0072 - val_accuracy: 0.0000e+00
# Epoch 99/1000
# 194/194 [==============================] - 0s 586us/sample - loss: 0.0068 - accuracy: 0.1289 - val_loss: 0.0076 - val_accuracy: 0.0000e+00
# Epoch 100/1000
# 194/194 [==============================] - 0s 572us/sample - loss: 0.0066 - accuracy: 0.1289 - val_loss: 0.0066 - val_accuracy: 0.0000e+00
# Epoch 101/1000
# 194/194 [==============================] - 0s 566us/sample - loss: 0.0067 - accuracy: 0.1289 - val_loss: 0.0082 - val_accuracy: 0.0000e+00
# Epoch 102/1000
# 194/194 [==============================] - 0s 575us/sample - loss: 0.0069 - accuracy: 0.1289 - val_loss: 0.0067 - val_accuracy: 0.0000e+00
# Epoch 103/1000
# 194/194 [==============================] - 0s 565us/sample - loss: 0.0067 - accuracy: 0.1289 - val_loss: 0.0088 - val_accuracy: 0.0000e+00
# Epoch 104/1000
# 194/194 [==============================] - 0s 559us/sample - loss: 0.0074 - accuracy: 0.1289 - val_loss: 0.0074 - val_accuracy: 0.0000e+00
# Epoch 105/1000
# 194/194 [==============================] - 0s 588us/sample - loss: 0.0066 - accuracy: 0.1289 - val_loss: 0.0069 - val_accuracy: 0.0000e+00

# %% [markdown]
#  ###  Modeling 예측

# %%
test_predict = tf.model.predict(testX)
MSE = mean_squared_error(testY.reshape(-1,1),test_predict)
RMSE = np.sqrt(MSE)

pred_score = 100 * ( 1 - (((test_predict - testY)**2).sum())/((testY**2).sum()))

print('MSE : {} , RMSE : {} , score : {}'.format(MSE,RMSE,pred_score))
np.array(min_max_y.inverse_transform(test_predict), dtype=np.int)[:10]
# Out:
# MSE : 0.006852117975927547 , RMSE : 0.08277752095785151 , score : 88.95741695607973
# array([[32],
#        [23],
#        [23],
#        [28],
#        [35],
#        [45],
#        [39],
#        [36],
#        [33],
#        [25]])

# %% [markdown]
#  ### 에러율 검출 시각화

# %%
plt.plot(h.history['loss'], label = 'loss', color = 'b')
plt.plot(h.history['val_loss'], label = 'val_loss', color = 'r')
plt.legend()
plt.show()

# %% [markdown]
#  ### 실제값 vs 예측값 시각화

# %%
Ty = min_max_y.inverse_transform(testY)
Tp = min_max_y.inverse_transform(test_predict)
Td = Tp - Ty

plt.plot(Ty,label = 'test')
plt.plot(Tp,label = 'predict')
plt.plot(Td,label = 'diff')
plt.plot(np.zeros(len(Td)),'--', color = 'black')
plt.xlabel("Time Period")
plt.ylabel("infection")
plt.legend()
plt.show()

# %% [markdown]
#  ### 학습 구간 - 예측구간 전체 시각화

# %%
t_axis = np.arange(0,len(xy))
s_axis = np.arange(0,seq_length)
a_axis = np.arange(len(s_axis),len(s_axis) + len(trainY))
b_axis = np.arange(len(s_axis) + len(a_axis),len(s_axis) + len(a_axis) + len(test_predict))

plt.figure(figsize=(15,6))
plt.scatter(t_axis,xy[:,-1],color = 'black',s = 10)
plt.plot(a_axis, min_max_y_fit.inverse_transform(trainY), alpha=0.7)
plt.plot(b_axis,min_max_y_fit.inverse_transform(test_predict), color='red', alpha=0.5, label='perd')
plt.plot(b_axis,min_max_y_fit.inverse_transform(testY), color='springgreen', label='actual')
plt.xlabel("Time Period")
plt.ylabel("infection")
plt.grid(b=True, axis='y', linestyle='--')
plt.legend(fontsize = 15)
plt.show()

# %% [markdown]
#  - Modeling Save Point

# %%
from datetime import datetime
from tensorflow.keras.models import model_from_json

if pred_score >=90 :
    # Save model
    model_json = tf.model.to_json()
    with open("./model_json/model_{}_score_{}.json".format(datetime.now().strftime('%Y_%m_%d'),int(pred_score*100)), "w") as json_file : 
        json_file.write(model_json)

    # Save model weights
    tf.model.save_weights("./weight_h5/model_weight_{}_score_{}.h5".format(datetime.now().strftime('%Y_%m_%d'),int(pred_score*100)))
    print("Saved model to disk")
    
    # load model model & witght
    json_file = open("./model_json/model_{}_score_{}.json".format(datetime.now().strftime('%Y_%m_%d'),int(pred_score*100)), "r")
    json_model = json_file.read()
    json_file.close()
    model = model_from_json(json_model)
    model.load_weights("./weight_h5/model_weight_{}_score_{}.h5".format(datetime.now().strftime('%Y_%m_%d'),int(pred_score*100)))
    
    
else:
    print('모델 점수가 90점 미만입니다.{}'.format(pred_score))
# Out:
# 모델 점수가 90점 미만입니다.88.95741695607973

# %% [markdown]
# # Predict confirmed count

# %% [markdown]
# ## Case 별 추세선 시각화
# ### 신천지발 확진

# %%
data_col = ['exam_cnt', 'spread', 'policy', 'cfm_cnt']
periods = 12


# Case 신천지발 확진
# exam 2020-02-18 ~ 2020-05-06
prd_data, exam_diff_polyfit_, exam_diff_prd_ = series_diff(data = data, data_col = data_col,
                                             start_date = '2020-02-18',mid_date='2020-05-05',
                                             end_date='2020-05-06',
                                             col = data_col[0])

exam_prd_fit_, exam_diff_data_, exam_list_prd_ = polyfit_prd(exam_diff_polyfit_, exam_diff_prd_,
                                                     data_col[0])

# spread 2020-03-01 ~ 2020-05-15
_, spread_diff_polyfit_, spread_diff_prd_ = series_diff(data = data, data_col = data_col,
                                          start_date = '2020-02-18',mid_date='2020-05-05',
                                          end_date='2020-05-06',
                                          col = data_col[1])

spread_prd_fit_, spread_diff_data_, spread_list_prd_ = polyfit_prd(spread_diff_polyfit_,
                                                         spread_diff_prd_,
                                                         data_col[1])


fig = plt.figure(figsize=(70,50))
# exam
ax = fig.add_subplot(211)
ax.patch.set_facecolor('w')
ax.patch.set_alpha(0.1)

ax.plot(prd_data.loc['2020-02-01':,'exam_cnt'], label = 'exam_cnt_all')

ax.plot(exam_diff_data_.index, exam_diff_data_.exam_cnt, marker = '*', label='exam_cnt')
ax.plot(exam_diff_data_.index, exam_diff_data_.prd_exam_cnt, label='predict',linewidth=10)

ax.plot(exam_prd_fit_.index, exam_prd_fit_.exam_cnt, marker = '*', label='exam_cnt')
ax.plot(exam_prd_fit_.index, exam_prd_fit_.prd_exam_cnt, marker = 'o',linestyle='--', label='predict')
plt.xticks(rotation=60,fontsize=50)
plt.yticks(fontsize=50)
# plt.legend(fontsize=50)
plt.grid(b = True, axis='both')


# spread
ax = fig.add_subplot(212)
ax.patch.set_facecolor('w')
ax.patch.set_alpha(0.1)

ax.plot(prd_data.loc['2020-02-01':,'spread'], label = 'spread_all')

ax.plot(spread_diff_data_.index, spread_diff_data_.spread, marker = '*', label='spread')
ax.plot(spread_diff_data_.index, spread_diff_data_.prd_spread, label='predict',linewidth=10)

ax.plot(spread_prd_fit_.index, spread_prd_fit_.spread, marker = '*', label='spread')
ax.plot(spread_prd_fit_.index, spread_prd_fit_.prd_spread, marker = 'o',linestyle='--', label='predict')
plt.xticks(rotation=60,fontsize=50)
plt.yticks(fontsize=50)
# plt.legend(fontsize=50)
plt.grid(b = True, axis='both')

plt.show()
# Out:
# [7113.233566433564]
#  []
#  []
# exam_cnt 추세선 값  = w :  -42.7053752217932/ b : 9931.788331071915
# [0.11261305361305363]
#  []
#  []
# spread 추세선 값  = w :  -0.0029658699509445786/ b : 0.3083604703753958

# %% [markdown]
# ### 이태원발 확진

# %%
# Case 이태원발 확진

# exam 2020-05-06 ~ 2020-08-10
_, exam_diff_polyfit_, exam_diff_prd_ = series_diff(data = data, data_col = data_col,
                                             start_date = '2020-05-06',mid_date='2020-08-02',
                                             end_date='2020-08-03',
                                             col = data_col[0])

exam_prd_fit_, exam_diff_data_, exam_list_prd_ = polyfit_prd(exam_diff_polyfit_, exam_diff_prd_,
                                                     data_col[0])

# spread 2020-05-06 ~ 2020-08-10
_, spread_diff_polyfit_, spread_diff_prd_ = series_diff(data = data, data_col = data_col,
                                          start_date = '2020-05-06',mid_date='2020-08-02',
                                             end_date='2020-08-03',
                                          col = data_col[1])

spread_prd_fit_, spread_diff_data_, spread_list_prd_ = polyfit_prd(spread_diff_polyfit_,
                                                         spread_diff_prd_,
                                                         data_col[1])


fig = plt.figure(figsize=(70,50))
# exam
ax = fig.add_subplot(211)
ax.patch.set_facecolor('w')
ax.patch.set_alpha(0.1)

ax.plot(prd_data.loc['2020-02-01':,'exam_cnt'], label = 'exam_cnt_all')

ax.plot(exam_diff_data_.index, exam_diff_data_.exam_cnt, marker = '*', label='exam_cnt')
ax.plot(exam_diff_data_.index, exam_diff_data_.prd_exam_cnt, label='predict',linewidth=10)

ax.plot(exam_prd_fit_.index, exam_prd_fit_.exam_cnt, marker = '*', label='exam_cnt')
ax.plot(exam_prd_fit_.index, exam_prd_fit_.prd_exam_cnt, marker = 'o',linestyle='--', label='predict')
plt.xticks(rotation=60,fontsize=50)
plt.yticks(fontsize=50)
plt.legend(fontsize=50)
plt.grid(b = True, axis='both')


# spread
ax = fig.add_subplot(212)
ax.patch.set_facecolor('w')
ax.patch.set_alpha(0.1)

ax.plot(prd_data.loc['2020-02-01':,'spread'], label = 'spread_all')

ax.plot(spread_diff_data_.index, spread_diff_data_.spread, marker = '*', label='spread')
ax.plot(spread_diff_data_.index, spread_diff_data_.prd_spread, label='predict',linewidth=10)

ax.plot(spread_prd_fit_.index, spread_prd_fit_.spread, marker = '*', label='spread')
ax.plot(spread_prd_fit_.index, spread_prd_fit_.prd_spread, marker = 'o',linestyle='--', label='predict')
plt.xticks(rotation=60,fontsize=50)
plt.yticks(fontsize=50)
plt.legend(fontsize=50)
plt.grid(b = True, axis='both')

plt.show()
# Out:
# [9432.406041165461]
#  []
#  []
# exam_cnt 추세선 값  = w :  -25.501221112488142/ b : 11651.01227795193
# [0.1737407110398289]
#  []
#  []
# spread 추세선 값  = w :  -0.0005824342057301156/ b : 0.22441248693834898

# %% [markdown]
# ### 사랑제일교회 관련 확진

# %%
# Csee 8.15 집회발 확진

# exam 2020-08-15 ~ 2020-09-19
_, exam_diff_polyfit, exam_diff_prd = series_diff(data = data, data_col = data_col,
                                             start_date = '2020-08-03',mid_date='2020-09-21',
                                             end_date='2020-09-22',
                                             col = data_col[0])

exam_prd_fit, exam_diff_data, exam_list_prd = polyfit_prd(exam_diff_polyfit, exam_diff_prd,
                                                     data_col[0],periods=periods)

# spread 2020-08-15 ~ 2020-09-19
_, spread_diff_polyfit, spread_diff_prd = series_diff(data = data, data_col = data_col,
                                          start_date = '2020-08-03', mid_date='2020-09-21',
                                          end_date='2020-09-22',
                                          col = data_col[1])

spread_prd_fit, spread_diff_data, spread_list_prd = polyfit_prd(spread_diff_polyfit,
                                                         spread_diff_prd,
                                                         data_col[1],
                                                         periods=periods)

policy_list_prd = np.full(periods,2)

arr_prd = np.concatenate((exam_list_prd,spread_list_prd,policy_list_prd),axis=0).reshape(-1,periods).T

#qgrid.show_grid(spread_prd_fit)

fig = plt.figure(figsize=(70,50))


# exam
ax = fig.add_subplot(211)
ax.patch.set_facecolor('w')
ax.patch.set_alpha(0.1)

ax.plot(prd_data.loc['2020-02-01':,'exam_cnt'], label = 'exam_cnt_all')

ax.plot(exam_diff_data.index, exam_diff_data.exam_cnt, marker = '*', label='exam_cnt')
ax.plot(exam_diff_data.index, exam_diff_data.prd_exam_cnt, label='predict',linewidth=10)

ax.plot(exam_prd_fit.index, exam_prd_fit.exam_cnt, marker = '*', label='exam_cnt')
ax.plot(exam_prd_fit.index, exam_prd_fit.prd_exam_cnt, marker = 'o',linestyle='--', label='predict')
plt.xticks(rotation=60,fontsize=50)
plt.yticks(fontsize=50)
plt.legend(fontsize=50)
plt.grid(b = True, axis='both')


# spread
ax = fig.add_subplot(212)
ax.patch.set_facecolor('w')
ax.patch.set_alpha(0.1)

ax.plot(prd_data.loc['2020-02-01':,'spread'], label = 'spread_all')

ax.plot(spread_diff_data.index, spread_diff_data.spread, marker = '*', label='spread')
ax.plot(spread_diff_data.index, spread_diff_data.prd_spread, label='predict',linewidth=10)

ax.plot(spread_prd_fit.index, spread_prd_fit.spread, marker = '*', label='spread')
ax.plot(spread_prd_fit.index, spread_prd_fit.prd_spread, marker = 'o',linestyle='--', label='predict')
plt.xticks(rotation=60,fontsize=50)
plt.yticks(fontsize=50)
plt.legend(fontsize=50)
plt.grid(b = True, axis='both')

plt.show()
qgrid.show_grid(prd_data,show_toolbar=True)
# Out:
# [15913.440816326536]
#  [16030.309867947184, 16147.178919567832, 16264.04797118848, 16380.917022809128, 16497.786074429776, 16614.655126050427, 16731.524177671075, 16848.393229291723, 16965.26228091237, 17082.13133253302, 17199.000384153667, 17315.869435774315]
#  [16030.309867947184, 16147.178919567832, 16264.04797118848, 16380.917022809128, 16497.786074429776, 16614.655126050427, 16731.524177671075, 16848.393229291723, 16965.26228091237, 17082.13133253302, 17199.000384153667, 17315.869435774315]
# exam_cnt 추세선 값  = w :  116.86905162064834/ b : 10069.988235294119
# [1.3162995918367346]
#  [1.3169544777911164, 1.317609363745498, 1.3182642496998798, 1.3189191356542616, 1.3195740216086433, 1.3202289075630251, 1.320883793517407, 1.3215386794717885, 1.3221935654261703, 1.322848451380552, 1.3235033373349339, 1.3241582232893157]
#  [1.3169544777911164, 1.317609363745498, 1.3182642496998798, 1.3189191356542616, 1.3195740216086433, 1.3202289075630251, 1.320883793517407, 1.3215386794717885, 1.3221935654261703, 1.322848451380552, 1.3235033373349339, 1.3241582232893157]
# spread 추세선 값  = w :  0.0006548859543817529/ b : 1.283555294117647
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…

# %% [markdown]
# ## 예측 확진자 도출
# ### 전체 데이터 + 추세 데이터 스케일링

# %%
allX_scaler = scaler()
allY_scaler = scaler()
allP_scaler = scaler()

x_all = xy[:,:-1]
y_all = xy[:,[-1]]
prd_x_all = np.concatenate((xy[:,:-1],arr_prd),axis=0)

x_all_sc = allX_scaler.fit(x_all)
y_all_sc = allY_scaler.fit(y_all)
prd_x_all_sc = allP_scaler.fit(prd_x_all)

x_all = x_all_sc.transform(x_all)
y_all = y_all_sc.transform(y_all)
x_prd = prd_x_all_sc.transform(prd_x_all)

xy_sc = np.concatenate((x_all,y_all),axis = 1)

x_all , y_all = build_dataset(xy_sc,seq_length)
px_all = build_dataset_x(x_prd,seq_length)

px_all = px_all[-periods:]
px_all
# Out:
# 0번째
# [[0.00 0.01 0.00]
#  [0.00 0.01 0.00]
#  [0.00 0.01 0.00]
#  [0.02 0.01 0.00]] -> [0.00]
# ==========
# 1번째
# [[0.00 0.01 0.00]
#  [0.00 0.01 0.00]
#  [0.02 0.01 0.00]
#  [0.02 0.01 0.00]] -> [0.00]
# ==========
# 2번째
# [[0.00 0.01 0.00]
#  [0.02 0.01 0.00]
#  [0.02 0.01 0.00]
#  [0.04 0.00 0.00]] -> [0.00]
# ==========
# 3번째
# [[0.02 0.01 0.00]
#  [0.02 0.01 0.00]
#  [0.04 0.00 0.00]
#  [0.08 0.01 0.00]] -> [0.01]
# ==========
# 4번째
# [[0.02 0.01 0.00]
#  [0.04 0.00 0.00]
#  [0.08 0.01 0.00]
#  [0.13 0.02 0.00]] -> [0.05]
# ==========
# 5번째
# [[0.04 0.00 0.00]
#  [0.08 0.01 0.00]
#  [0.13 0.02 0.00]
#  [0.21 0.03 0.00]] -> [0.07]
# ==========
# 6번째
# [[0.08 0.01 0.00]
#  [0.13 0.02 0.00]
#  [0.21 0.03 0.00]
#  [0.19 0.11 0.00]] -> [0.07]
# ==========
# 7번째
# [[0.13 0.02 0.00]
#  [0.21 0.03 0.00]
#  [0.19 0.11 0.00]
#  [0.27 0.09 0.00]] -> [0.04]
# ==========
# 8번째
# [[0.21 0.03 0.00]
#  [0.19 0.11 0.00]
#  [0.27 0.09 0.00]
#  [0.32 0.06 0.00]] -> [0.07]
# ==========
# 9번째
# [[0.19 0.11 0.00]
#  [0.27 0.09 0.00]
#  [0.32 0.06 0.00]
#  [0.55 0.09 0.00]] -> [0.10]
# ==========
# 10번째
# [[0.27 0.09 0.00]
#  [0.32 0.06 0.00]
#  [0.55 0.09 0.00]
#  [0.54 0.11 0.00]] -> [0.06]
# ==========
# 0번째
# [[0.00 0.01 0.00]
#  [0.00 0.01 0.00]
#  [0.00 0.01 0.00]
#  [0.02 0.01 0.00]]
# ==========
# 1번째
# [[0.00 0.01 0.00]
#  [0.00 0.01 0.00]
#  [0.02 0.01 0.00]
#  [0.02 0.01 0.00]]
# ==========
# 2번째
# [[0.00 0.01 0.00]
#  [0.02 0.01 0.00]
#  [0.02 0.01 0.00]
#  [0.04 0.00 0.00]]
# ==========
# 3번째
# [[0.02 0.01 0.00]
#  [0.02 0.01 0.00]
#  [0.04 0.00 0.00]
#  [0.08 0.01 0.00]]
# ==========
# 4번째
# [[0.02 0.01 0.00]
#  [0.04 0.00 0.00]
#  [0.08 0.01 0.00]
#  [0.13 0.02 0.00]]
# ==========
# 5번째
# [[0.04 0.00 0.00]
#  [0.08 0.01 0.00]
#  [0.13 0.02 0.00]
#  [0.21 0.03 0.00]]
# ==========
# 6번째
# [[0.08 0.01 0.00]
#  [0.13 0.02 0.00]
#  [0.21 0.03 0.00]
#  [0.19 0.11 0.00]]
# ==========
# 7번째
# [[0.13 0.02 0.00]
#  [0.21 0.03 0.00]
#  [0.19 0.11 0.00]
#  [0.27 0.09 0.00]]
# ==========
# 8번째
# [[0.21 0.03 0.00]
#  [0.19 0.11 0.00]
#  [0.27 0.09 0.00]
#  [0.32 0.06 0.00]]
# ==========
# 9번째
# [[0.19 0.11 0.00]
#  [0.27 0.09 0.00]
#  [0.32 0.06 0.00]
#  [0.55 0.09 0.00]]
# ==========
# 10번째
# [[0.27 0.09 0.00]
#  [0.32 0.06 0.00]
#  [0.55 0.09 0.00]
#  [0.54 0.11 0.00]]
# ==========
# array([[[0.54, 0.19, 0.80],
#         [0.32, 0.14, 0.80],
#         [0.20, 0.12, 0.80],
#         [0.58, 0.25, 0.80]],
#
#        [[0.32, 0.14, 0.80],
#         [0.20, 0.12, 0.80],
#         [0.58, 0.25, 0.80],
#         [0.69, 0.41, 0.80]],
#
#        [[0.20, 0.12, 0.80],
#         [0.58, 0.25, 0.80],
#         [0.69, 0.41, 0.80],
#         [0.69, 0.41, 0.80]],
#
#        [[0.58, 0.25, 0.80],
#         [0.69, 0.41, 0.80],
#         [0.69, 0.41, 0.80],
#         [0.70, 0.41, 0.80]],
#
#        [[0.69, 0.41, 0.80],
#         [0.69, 0.41, 0.80],
#         [0.70, 0.41, 0.80],
#         [0.70, 0.41, 0.80]],
#
#        [[0.69, 0.41, 0.80],
#         [0.70, 0.41, 0.80],
#         [0.70, 0.41, 0.80],
#         [0.71, 0.41, 0.80]],
#
#        [[0.70, 0.41, 0.80],
#         [0.70, 0.41, 0.80],
#         [0.71, 0.41, 0.80],
#         [0.71, 0.41, 0.80]],
#
#        [[0.70, 0.41, 0.80],
#         [0.71, 0.41, 0.80],
#         [0.71, 0.41, 0.80],
#         [0.72, 0.41, 0.80]],
#
#        [[0.71, 0.41, 0.80],
#         [0.71, 0.41, 0.80],
#         [0.72, 0.41, 0.80],
#         [0.72, 0.41, 0.80]],
#
#        [[0.71, 0.41, 0.80],
#         [0.72, 0.41, 0.80],
#         [0.72, 0.41, 0.80],
#         [0.73, 0.41, 0.80]],
#
#        [[0.72, 0.41, 0.80],
#         [0.72, 0.41, 0.80],
#         [0.73, 0.41, 0.80],
#         [0.73, 0.41, 0.80]],
#
#        [[0.72, 0.41, 0.80],
#         [0.73, 0.41, 0.80],
#         [0.73, 0.41, 0.80],
#         [0.74, 0.41, 0.80]]])

# %% [markdown]
# ### 모델에 나온 결과값 도출

# %%
y_prd = tf.model.predict(px_all)
prd_val = list(y_all_sc.inverse_transform(y_prd).astype(np.int).flatten())
prd_val
# Out:
# [26, 34, 40, 44, 46, 45, 45, 45, 44, 44, 44, 43]

# %% [markdown]
# ### 모델 예측 결과 및 시각화

# %%
arr_prd_day = np.concatenate((arr_prd,np.array(prd_val).reshape(-1,1)),axis=1)
prd_idx = pd.date_range(start= prd_data.index[-1], periods= periods + 1, closed='right')
df_prd_day = pd.DataFrame(arr_prd_day,index=prd_idx,columns=data_col)

df_all = pd.concat([prd_data,df_prd_day])
plt.figure(figsize=(20,10))
plt.plot(df_all.loc['2020-09-01':,'cfm_cnt'],marker='o')
plt.plot(df_prd_day.index,df_prd_day.cfm_cnt,marker = 'o')
plt.grid(b=True,axis='both')
plt.xticks(rotation = 60, fontsize=20)
plt.show()
qgrid.show_grid(df_prd_day,show_toolbar=True)
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…
